# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.optimize import leastsq
from scipy import constants as C
from statistics import mean
from loadvai2 import loadVAI

# %%
    v,a,i=loadVAI()
    
    v = np.array(v)
    v = [float(x) for x in v]
    
    A = np.array(a)
    A = [float(x) for x in A]
    
    i = np.array(i)
    i = [float(x) for x in i]
# Out:
# ------------- now is irony------------
# --------------- now is valence------------
#  ----------------now is arousal-----------

# %%
# 误差函数
def residuals(p):
    k, b = p
    return A - (k * v + b)
 
r = leastsq(residuals, [1, 0])
K, B = r[0]
print("斜率k =", K, "截距b =", B)
a, b = np.exp(B), K
print("常量a =", a, "常量b =", b)
#k = C.electron_volt / (b * 300)
#print("玻尔兹曼常量k =", k, "J/K")
# Out:
# 斜率k = 1.0 截距b = 1.6768518279
# 常量a = 5.34869083862 常量b = 1.0
# C:\Anaconda3\envs\py34\lib\site-packages\ipykernel\__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
plt.scatter(v, A)
plt.plot(v, v * K + B, linewidth=2)
plt.xlabel('Valence')
plt.ylabel('Arousal')
plt.grid(True)
plt.title('Plot : VA')
plt.show()
# Out:
# C:\Anaconda3\envs\py34\lib\site-packages\ipykernel\__main__.py:2: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   from ipykernel import kernelapp as app
